# %%
# !pip install SQLAlchemy==1.4.47
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.10
#     Uninstalling SQLAlchemy-2.0.10:
#       Successfully uninstalled SQLAlchemy-2.0.10
# ...

# %%
! kill -9 $(ps -A | grep python | awk '{print $1}')

# %%
# %load_ext sql

# %%
# %sql postgresql://admin:xxxxxxxx@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev

# %%
# %%sql
#
# CREATE TABLE RAW_DATA.CODE_DETAIL
# (
#     CODE_SEQ INT PRIMARY KEY
#   , CODE VARCHAR(10)
#   , CODE_CATEGORY VARCHAR(10)
#   , CODE_NM VARCHAR(32)
#   , PARENT_CODE VARCHAR(10)
# )
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# DROP TABLE RAW_DATA.CODE_DETAIL;
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# COPY RAW_DATA.CODE_DETAIL
# FROM 's3://tour-dashboard-4-2/csv_data/CODE_DETAIL.csv'
# credentials 'aws_iam_role=arn:aws:iam::433690009634:role/redshift.read.s3'
# delimiter ',' dateformat 'auto' timeformat 'auto' IGNOREHEADER 1 removequotes ACCEPTINVCHARS ESCAPE;
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# Done.
# []

# %%
# %%sql
#
# SELECT *
#   FROM sys_load_error_detail;
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# 3 rows affected.
# ...

# %%
# %%sql
#
# DELETE
#   FROM RAW_DATA.CODE_DETAIL;
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# 268 rows affected.
# []

# %%
# %%sql
#
# SELECT *
#   FROM RAW_DATA.CODE_DETAIL;
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# 268 rows affected.
# [(1, '1', 'AREA', '서울', ''),
#  (2, '2', 'AREA', '인천', ''),
#  (3, '3', 'AREA', '대전', ''),
#  (4, '4', 'AREA', '대구', ''),
#  (5, '5', 'AREA', '광주', ''),
#  (6, '6', 'AREA', '부산', ''),
#  (7, '7', 'AREA', '울산', ''),
#  (8, '8', 'AREA', '세종', ''),
#  (9, '31', 'AREA', '경기', ''),
#  (10, '32', 'AREA', '강원', ''),
#  (11, '33', 'AREA', '충북', ''),
#  (12, '34', 'AREA', '충남', ''),
#  (13, '35', 'AREA', '경북', ''),
#  (14, '36', 'AREA', '경남', ''),
#  (15, '37', 'AREA', '전북', ''),
#  (16, '38', 'AREA', '전남', ''),
#  (17, '39', 'AREA', '제주', ''),
#  (18, '12', 'FACILITY', '관광지', ''),
#  (19, '14', 'FACILITY', '문화시설', ''),
#  (20, '25', 'FACILITY', '여행코스', ''),
#  (21, '28', 'FACILITY', '레포츠', ''),
#  (22, '32', 'FACILITY', '숙박', ''),
#  (23, '38', 'FACILITY', '쇼핑', ''),
#  (24, '39', 'FACILITY', '음식점', ''),
#  (25, '1', 'DAY', '월', ''),
# ...

# %%
# %%sql
#
# COMMIT;
# Out:
#  * postgresql://admin:***@tableau-project-4-2.433690009634.us-west-2.redshift-serverless.amazonaws.com:5439/dev
# Done.
# []
